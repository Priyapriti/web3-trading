# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/fear_greed_index.csv')

# %%
df.shape
# Out:
# (2644, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   int64
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 82.8+ KB

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   int64
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 82.8+ KB

# %%
print("Dataset Summary:")
print(df.describe())
print("\nClassification Counts:")
print(df['classification'].value_counts())
# Out:
# Dataset Summary:
#           timestamp        value                           date
# count  2.644000e+03  2644.000000                           2644
# mean   1.631899e+09    46.981089  2021-09-17 11:44:45.022692864
# min    1.517463e+09     5.000000            2018-02-01 00:00:00
# 25%    1.574811e+09    28.000000            2019-11-26 18:00:00
# 50%    1.631900e+09    46.000000            2021-09-17 12:00:00
# 75%    1.688989e+09    66.000000            2023-07-10 06:00:00
# max    1.746164e+09    95.000000            2025-05-02 00:00:00
# std    6.597967e+07    21.827680                            NaN
#
# Classification Counts:
# classification
# Fear             781
# Greed            633
# Extreme Fear     508
# Neutral          396
# Extreme Greed    326
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 6))
plt.plot(df['date'], df['value'], color='purple', label='Fear & Greed Index')
plt.title('Fear & Greed Index Over Time')
plt.xlabel('Date')
plt.ylabel('Index Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
df['classification'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Frequency of Market Sentiment')
plt.xlabel('Sentiment Classification')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
trader_df = pd.read_csv('/content/historical_data.csv')

# %%
trader_df['Timestamp IST'] = pd.to_datetime(trader_df['Timestamp IST'], format='%d-%m-%Y %H:%M')
trader_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  datetime64[ns]
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
#  15  Timestamp         211224 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(1), object(5)
# memory usage: 24.4+ MB

# %%
trader_df.columns
trader_df.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# 0         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 1         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 2         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 3         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 4         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
#
#    Crossed       Fee      Trade ID     Timestamp
# 0     True  0.345404  8.950000e+14  1.730000e+12
# 1     True  0.005600  4.430000e+14  1.730000e+12
# 2     True  0.050431  6.600000e+14  1.730000e+12
# 3     True  0.050043  1.080000e+15  1.730000e+12
# 4     True  0.003055  1.050000e+15  1.730000e+12

# %%
trader_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  datetime64[ns]
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
#  15  Timestamp         211224 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(1), object(5)
# memory usage: 24.4+ MB

# %%
trader_df['date'] = trader_df['Timestamp IST'].dt.date

# %%
trader_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  datetime64[ns]
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
#  15  Timestamp         211224 non-null  float64
#  16  date              211224 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(1), object(6)
# memory usage: 26.0+ MB

# %%
sentiment_df = pd.read_csv('/content/fear_greed_index.csv')
sentiment_df['date'] = pd.to_datetime(sentiment_df['date']).dt.date

# %%
merged_df = pd.merge(trader_df, sentiment_df, on='date', how='left')

# %%
avg_pnl_by_sentiment = merged_df.groupby('classification')['Closed PnL'].mean()
print("Average Profit/Loss by Market Sentiment:")
print(avg_pnl_by_sentiment)
# Out:
# Average Profit/Loss by Market Sentiment:
# classification
# Extreme Fear     34.537862
# Extreme Greed    67.892861
# Fear             54.290400
# Greed            42.743559
# Neutral          34.307718
# Name: Closed PnL, dtype: float64

# %%
avg_pnl_by_sentiment.plot(kind='bar', color='orange')
plt.title('Average Trader Profit/Loss by Market Sentiment')
plt.xlabel('Market Sentiment')
plt.ylabel('Average Closed PnL')
plt.grid(True)
plt.show()

# %%
  # avg_leverage_by_sentiment = merged_df.groupby('classification')['leverage'].mean()
  # print("\nAverage Leverage by Market Sentiment:")
  # print(avg_leverage_by_sentiment)

  # avg_leverage_by_sentiment.plot(kind='bar', color='green')
  # plt.title('Average Leverage Used by Market Sentiment')
  # plt.xlabel('Market Sentiment')
  # plt.ylabel('Average Leverage')
  # plt.grid(True)
  # plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-610576791.py in <cell line: 0>()
# ----> 1 avg_leverage_by_sentiment = merged_df.groupby('classification')['leverage'].mean()
#       2 print("\nAverage Leverage by Market Sentiment:")
#       3 print(avg_leverage_by_sentiment)
#       4
#       5 avg_leverage_by_sentiment.plot(kind='bar', color='green')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1949                 "Use a list instead."
#    1950             )
# -> 1951         return super().__getitem__(key)
#    1952
#    1953     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     242         else:
#     243             if key not in self.obj:
# --> 244                 raise KeyError(f"Column not found: {key}")
#     245             ndim = self.obj[key].ndim
#     246             return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: leverage'

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  datetime64[ns]
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
#  15  Timestamp         211224 non-null  float64
#  16  date              211224 non-null  object
#  17  timestamp         211218 non-null  float64
#  18  value             211218 non-null  float64
#  19  classification    211218 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(10), int64(1), object(7)
# memory usage: 30.8+ MB

# %%
merged_df.describe()
# Out:
#        Execution Price   Size Tokens      Size USD  \
# count    211224.000000  2.112240e+05  2.112240e+05
# mean      11414.723350  4.623365e+03  5.639451e+03
# min           0.000005  8.740000e-07  0.000000e+00
# 25%           4.854700  2.940000e+00  1.937900e+02
# 50%          18.280000  3.200000e+01  5.970450e+02
# 75%         101.580000  1.879025e+02  2.058960e+03
# max      109004.000000  1.582244e+07  3.921431e+06
# std       29447.654868  1.042729e+05  3.657514e+04
#
#                        Timestamp IST  Start Position     Closed PnL  \
# count                         211224    2.112240e+05  211224.000000
# mean   2025-01-31 12:04:22.915009792   -2.994625e+04      48.749001
# min              2023-05-01 01:06:00   -1.433463e+07 -117990.104100
# 25%              2024-12-31 21:00:45   -3.762311e+02       0.000000
# 50%              2025-02-24 18:55:00    8.472793e+01       0.000000
# 75%              2025-04-02 18:22:00    9.337278e+03       5.792797
# max              2025-05-01 12:13:00    3.050948e+07  135329.090100
# std                              NaN    6.738074e+05     919.164828
#
#            Order ID            Fee      Trade ID     Timestamp     timestamp  \
# count  2.112240e+05  211224.000000  2.112240e+05  2.112240e+05  2.112180e+05
# mean   6.965388e+10       1.163967  5.628549e+14  1.737744e+12  1.738301e+09
# min    1.732711e+08      -1.175712  0.000000e+00  1.680000e+12  1.682919e+09
# 25%    5.983853e+10       0.016121  2.810000e+14  1.740000e+12  1.735623e+09
# 50%    7.442939e+10       0.089578  5.620000e+14  1.740000e+12  1.740375e+09
# 75%    8.335543e+10       0.393811  8.460000e+14  1.740000e+12  1.743572e+09
# max    9.014923e+10     837.471593  1.130000e+15  1.750000e+12  1.746077e+09
# std    1.835753e+10       6.758854  3.257565e+14  8.689920e+09  8.029302e+06
#
#                value
# count  211218.000000
# mean       51.649656
# min        10.000000
# 25%        33.000000
# 50%        49.000000
# 75%        72.000000
# max        94.000000
# std        21.012784

# %%
merged_df.columns = merged_df.columns.str.strip().str.lower()
print("Cleaned columns:")
print(merged_df.columns.tolist())
# Out:
# Cleaned columns:
# ['account', 'coin', 'execution price', 'size tokens', 'size usd', 'side', 'timestamp ist', 'start position', 'direction', 'closed pnl', 'transaction hash', 'order id', 'crossed', 'fee', 'trade id', 'timestamp', 'date', 'timestamp', 'value', 'classification']

# %%
risk_by_sentiment = merged_df.groupby('classification')['closed pnl'].std()
print("Risk (PnL Std Dev) by Market Sentiment:")
print(risk_by_sentiment)

risk_by_sentiment.plot(kind='bar', color='red')
plt.title('Risk Level by Market Sentiment')
plt.xlabel('Market Sentiment')
plt.ylabel('PnL Standard Deviation')
plt.grid(True)
plt.show()
# Out:
# Risk (PnL Std Dev) by Market Sentiment:
# classification
# Extreme Fear     1136.056091
# Extreme Greed     766.828294
# Fear              935.355438
# Greed            1116.028390
# Neutral           517.122220
# Name: closed pnl, dtype: float64

# %%
volume_by_sentiment = merged_df.groupby('classification')['size usd'].sum()
print("\nTotal Trade Volume by Market Sentiment:")
print(volume_by_sentiment)

volume_by_sentiment.plot(kind='bar', color='blue')
plt.title('Trade Volume by Market Sentiment')
plt.xlabel('Market Sentiment')
plt.ylabel('Total Trade Size')
plt.grid(True)
plt.show()
# Out:
# Total Trade Volume by Market Sentiment:
# classification
# Extreme Fear     1.144843e+08
# Extreme Greed    1.244652e+08
# Fear             4.833248e+08
# Greed            2.885825e+08
# Neutral          1.802421e+08
# Name: size usd, dtype: float64

# %%
position_by_sentiment = merged_df.groupby('classification')['start position'].mean()
print("\nAverage Start Position by Market Sentiment:")
print(position_by_sentiment)

position_by_sentiment.plot(kind='bar', color='purple')
plt.title('Average Start Position by Market Sentiment')
plt.xlabel('Market Sentiment')
plt.ylabel('Average Start Position')
plt.grid(True)
plt.show()
# Out:
# Average Start Position by Market Sentiment:
# classification
# Extreme Fear      -2322.304587
# Extreme Greed     19518.990812
# Fear               8709.824822
# Greed           -151088.546635
# Neutral             144.002263
# Name: start position, dtype: float64
